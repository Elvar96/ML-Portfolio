# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dataset=pd.read_csv(r"C:\Users\Lenovo\Desktop\Machine Learning\hour.csv")

# %%
dataset.head(5)
# Out:
#    instant      dteday  season  yr  mnth  hr  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1   0        0        6           0
# 1        2  2011-01-01       1   0     1   1        0        6           0
# 2        3  2011-01-01       1   0     1   2        0        6           0
# 3        4  2011-01-01       1   0     1   3        0        6           0
# 4        5  2011-01-01       1   0     1   4        0        6           0
#
#    weathersit  temp   atemp   hum  windspeed  casual  registered  cnt
# 0           1  0.24  0.2879  0.81        0.0       3          13   16
# 1           1  0.22  0.2727  0.80        0.0       8          32   40
# 2           1  0.22  0.2727  0.80        0.0       5          27   32
# 3           1  0.24  0.2879  0.75        0.0       3          10   13
# 4           1  0.24  0.2879  0.75        0.0       0           1    1

# %%
dataset.tail()
# Out:
#        instant      dteday  season  yr  mnth  hr  holiday  weekday  \
# 17374    17375  2012-12-31       1   1    12  19        0        1
# 17375    17376  2012-12-31       1   1    12  20        0        1
# 17376    17377  2012-12-31       1   1    12  21        0        1
# 17377    17378  2012-12-31       1   1    12  22        0        1
# 17378    17379  2012-12-31       1   1    12  23        0        1
#
#        workingday  weathersit  temp   atemp   hum  windspeed  casual  \
# 17374           1           2  0.26  0.2576  0.60     0.1642      11
# 17375           1           2  0.26  0.2576  0.60     0.1642       8
# 17376           1           1  0.26  0.2576  0.60     0.1642       7
# 17377           1           1  0.26  0.2727  0.56     0.1343      13
# 17378           1           1  0.26  0.2727  0.65     0.1343      12
#
#        registered  cnt
# 17374         108  119
# 17375          81   89
# 17376          83   90
# 17377          48   61
# 17378          37   49

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17379 entries, 0 to 17378
# Data columns (total 17 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   instant     17379 non-null  int64
#  1   dteday      17379 non-null  object
#  2   season      17379 non-null  int64
#  3   yr          17379 non-null  int64
#  4   mnth        17379 non-null  int64
#  5   hr          17379 non-null  int64
#  6   holiday     17379 non-null  int64
#  7   weekday     17379 non-null  int64
#  8   workingday  17379 non-null  int64
#  9   weathersit  17379 non-null  int64
#  10  temp        17379 non-null  float64
#  11  atemp       17379 non-null  float64
#  12  hum         17379 non-null  float64
#  13  windspeed   17379 non-null  float64
#  14  casual      17379 non-null  int64
#  15  registered  17379 non-null  int64
#  16  cnt         17379 non-null  int64
# dtypes: float64(4), int64(12), object(1)
# memory usage: 2.3+ MB

# %%
dataset.describe()
# Out:
#           instant        season            yr          mnth            hr  \
# count  17379.0000  17379.000000  17379.000000  17379.000000  17379.000000
# mean    8690.0000      2.501640      0.502561      6.537775     11.546752
# std     5017.0295      1.106918      0.500008      3.438776      6.914405
# min        1.0000      1.000000      0.000000      1.000000      0.000000
# 25%     4345.5000      2.000000      0.000000      4.000000      6.000000
# 50%     8690.0000      3.000000      1.000000      7.000000     12.000000
# 75%    13034.5000      3.000000      1.000000     10.000000     18.000000
# max    17379.0000      4.000000      1.000000     12.000000     23.000000
#
#             holiday       weekday    workingday    weathersit          temp  \
# count  17379.000000  17379.000000  17379.000000  17379.000000  17379.000000
# mean       0.028770      3.003683      0.682721      1.425283      0.496987
# ...

# %%
data=dataset[['casual' ,'cnt']]


#Input---------X

X=data['casual']


#Output----------y

y=data['cnt']

# %%
type(X)
# Out:
# pandas.core.series.Series

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
#Create a figure

plt.figure(figsize=(8,8))

sns.scatterplot(data=dataset,x='casual',y='cnt',color='orange')
plt.title('casual--cnt')
plt.show()

# %%
#Let's import Linear regression model from sklearn.

from sklearn.linear_model import LinearRegression

# %%
Lr=LinearRegression()

# %%
X.shape
# Out:
# (17379,)

# %%
X=X.values.reshape(-1,1)

# %%
y.shape
# Out:
# (17379,)

# %%
y=y.values.reshape(-1,1)

# %%
#Let's import train test split 

# %70 --Train Data
# %30 --Test Data

# Train Data = X_train, y_train
# Test Data = X_test, y_test

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=100)

# %%
X_train.shape
# Out:
# (12165, 1)

# %%
y_train.shape
# Out:
# (12165, 1)

# %%
X_test.shape
# Out:
# (5214, 1)

# %%
y_test.shape
# Out:
# (5214, 1)

# %%
# Let's fit Train Data

# %%
Lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
#Let's calculate intercept and Coef

# %%
Lr.intercept_
# Out:
# array([99.10372275])

# %%
Lr.coef_
# Out:
# array([[2.52388881]])

# %%
#y=B0+B1X

#B0=11.35
#B1=-0.63

#y=9.18+0.61X

# %%
# Now we need to predict Test Data

# %%
y_pred =Lr.predict(X_test)

# %%
y_pred[0:10]
# Out:
# array([[308.58649383],
#        [126.86649964],
#        [159.67705414],
#        [144.53372129],
#        [152.10538772],
#        [129.39038844],
#        [104.15150036],
#        [116.7709444 ],
#        [106.67538917],
#        [121.81872202]])

# %%
y_test[0:10]
# Out:
# array([[586],
#        [ 52],
#        [187],
#        [140],
#        [122],
#        [ 95],
#        [  4],
#        [ 79],
#        [187],
#        [ 15]], dtype=int64)

# %%
y_pred.shape
# Out:
# (5214, 1)

# %%
y_test.shape
# Out:
# (5214, 1)

# %%
#We should create a figure to show real and prediction data 

# Original label -- y_test

#Prediction label -- y_pred

# Input --X_test

# %%
# Original Data ---Grand Truth 

fig,ax = plt.subplots(figsize =(8,8))
ax.scatter(X_test,y_test, label = 'Grand Truth', color ='orange')

# Prediction Data 

plt.plot(X_test,y_pred, label ='Prediction', color ='red')
         

    
plt.title('Casual-cnt')
plt.xlabel('Casual')
plt.ylabel('cnt')
plt.legend(loc='upper right')
plt.show()

# %%
#Let's see changes in each prediction point
indexs =range(1,5215)

#Original Data---- Grand Truth
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(indexs, y_test, label ='Grand Truth', color ='red', linewidth =2)

# Prediction

ax.plot(indexs, y_pred, label = 'Prediction', color ='green', linewidth =2)

plt.title('Grand Truth--Prediction')
plt.xlabel('Data Index')
plt.ylabel('cnt')
plt.legend(loc='upper left')
plt.show()

# %%
#let's find residuls on the figure ( y_test-y_pred)

# %%
import numpy as np

# %%
#Residuals
indexs =range(1,5215)

#Original Data---- Grand Truth
fig,ax=plt.subplots(figsize=(12,8))
ax.plot(indexs, y_test-y_pred, label ='Residuals', color ='orange', linewidth =2)

# Prediction

ax.plot(indexs, np.zeros(5214), color ='green', linewidth =2)

plt.title('Error--Residuals')
plt.xlabel('Data Index')
plt.ylabel('cnt')
plt.legend(loc='upper left')
plt.show()

# %%
#let's control the model

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
#let's calculate R^2

# %%
R_2=r2_score(y_test,y_pred)
R_2
# Out:
# 0.48049732244713617

# %%
#Let's calculate MSE

# %%
mse = mean_squared_error(y_test,y_pred)
mse
# Out:
# 17017.04480885571

# %%
#Let's calculate RMSE

import math 

RMSE =math.sqrt(mse)
RMSE
# Out:
# 130.44939558639476
